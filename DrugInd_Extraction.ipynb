# %%
import os,sys,re,json,logging,yaml
import pandas as pd
from pandas.io.sql import read_sql_query
import psycopg2,psycopg2.extras
import numpy as np

# %% [markdown]
# # Notes 12/6/21
# ## ToDo
# * Adjust all hard-coding to functions, with drug_name input instead of specific for gabapentin
# * Adjust MeSH type extraction to prioritize mesh_list when present

# %% [markdown]
# # 1.AACT
# AACT is a publicly available relational database that contains all information (protocol and result data elements) about every study registered in ClinicalTrials.gov. Content is downloaded from ClinicalTrials.gov daily and loaded into AACT.
#
# https://aact.ctti-clinicaltrials.org/
#
# **Utility for project**:
# * **"Evidence assessment"** gauge - is there an ongoing trial for a specific indication?
# * Extract MeSH terms, specified as **mesh_type** to differentiate between direct association vs. hierarchical traversals
#     * mesh-list is the extracted concept
#     * mesh-ancestor is an ancestor of that concept

# %% [markdown]
# ### 1a. Connect to Database

# %%
dsn_AACT = ("host='aact-db.ctti-clinicaltrials.org' port='5432' dbname='aact' user='khs2138' password='Max0730!'")
dbcon_AACT = psycopg2.connect(dsn_AACT)
dbcon_AACT.cursor_factory = psycopg2.extras.DictCursor
dbcon_AACT
# Out:
# <connection object at 0x7fac724d2eb0; dsn: 'user=khs2138 password=xxx dbname=aact host=aact-db.ctti-clinicaltrials.org port=5432', closed: 0>

# %% [markdown]
# ## 1b. Interventions + Conditions: SQL Extract
# * STUDIES:
#     * NCT_ID
# * CONDITIONS:
#     * Condition name
# * INTERVENTIONS:
#     * Name - Drug of choice - filter by gabapentin
#     * Intervention_type - ensure drug treatment
# * BROWSE_INTERVENTIONS:
#     * MeSH terms for internvetions
#     * MeSH_type for interventions
# *  BROWSE_CONDITIONS:
#     * MeSH terms for conditions
#     * MeSH_type for conditions

# %%
sql = """\
SELECT 
	h.*,
    i.mesh_term as cond_mesh,
    i.downcase_mesh_term as d_cond_mesh,
    i.mesh_type 
FROM
	(SELECT 
    	f.*,
        g.mesh_term as drug_mesh,
        g.downcase_mesh_term as d_drug_mesh 
FROM
	(SELECT 
    	e.nct_id,
        e.intervention_name,
        e.condition_name,
        e.intervention_type 
FROM
	(SELECT 
    	c.*,
        d.name as condition_name,
        d.downcase_name 
FROM
	(SELECT 
    	a.nct_id,
        a.name as intervention_name,
        a.intervention_type,
        b.overall_status,
        b.why_stopped,
        b.phase,
        b.brief_title 
FROM
	interventions a
LEFT OUTER JOIN
	studies b
ON
	a.nct_id = b.nct_id
WHERE
	a.name like '%gabapentin%' or a.name like '%Gabapentin%') c
LEFT OUTER JOIN    
	conditions d
ON 
	c.nct_id = d.nct_id) e) f
LEFT OUTER JOIN
	browse_interventions g
ON
	f.nct_id = g.nct_id 
WHERE g.downcase_mesh_term like 'gabapentin') h
LEFT OUTER JOIN
	browse_conditions i
ON 
	h.nct_id = i.nct_id;
"""
logging.debug(f"SQL: {sql}")
aact_sql_extract = read_sql_query(sql, dbcon_AACT)
aact_sql_extract
# Out:
#            nct_id intervention_name                      condition_name  \
# 0     NCT04860141  Gabapentin 600mg  Dental Pain and Sensation Disorder
# 1     NCT04860141  Gabapentin 600mg  Dental Pain and Sensation Disorder
# 2     NCT04860141  Gabapentin 600mg  Dental Pain and Sensation Disorder
# 3     NCT04860141  Gabapentin 600mg  Dental Pain and Sensation Disorder
# 4     NCT04860141  Gabapentin 600mg  Dental Pain and Sensation Disorder
# ...           ...               ...                                 ...
# 6401  NCT05024825        Gabapentin                 Pain, Postoperative
# 6402  NCT05024825        Gabapentin                 Pain, Postoperative
# 6403  NCT05024825        Gabapentin                 Pain, Postoperative
# 6404  NCT05024825        Gabapentin                 Pain, Postoperative
# 6405  NCT05024825        Gabapentin                 Pain, Postoperative
#
#      intervention_type   drug_mesh d_drug_mesh                    cond_mesh  \
# 0                 Drug  Gabapentin  gabapentin          Sensation Disorders
# 1                 Drug  Gabapentin  gabapentin          Pain, Postoperative
# 2                 Drug  Gabapentin  gabapentin  Postoperative Complications
# 3                 Drug  Gabapentin  gabapentin         Pathologic Processes
# 4                 Drug  Gabapentin  gabapentin                         Pain
# ...                ...         ...         ...                          ...
# 6401              Drug  Gabapentin  gabapentin          Pain, Postoperative
# 6402              Drug  Gabapentin  gabapentin  Postoperative Complications
# 6403              Drug  Gabapentin  gabapentin         Pathologic Processes
# 6404              Drug  Gabapentin  gabapentin                         Pain
# 6405              Drug  Gabapentin  gabapentin    Neurologic Manifestations
#
#                       d_cond_mesh      mesh_type
# 0             sensation disorders      mesh-list
# 1             pain, postoperative      mesh-list
# 2     postoperative complications  mesh-ancestor
# 3            pathologic processes  mesh-ancestor
# 4                            pain  mesh-ancestor
# ...                           ...            ...
# 6401          pain, postoperative      mesh-list
# 6402  postoperative complications  mesh-ancestor
# 6403         pathologic processes  mesh-ancestor
# 6404                         pain  mesh-ancestor
# 6405    neurologic manifestations  mesh-ancestor
#
# [6406 rows x 9 columns]

# %% [markdown]
# ## 1c. Extract all treat-relationships from Clinical Trial data for drug in question

# %%
# Pull out the necessary columns: 
## NCT_ID: for trial reference
## drug_mesh: for the drug's mesh name 
#### (this should be the same throughout the table since we're pulling above for only ONE drug in question)
## cond_mesh: for the condition mesh terms
## mesh_type: for whether that is directly extracted from clinical trial data OR is an ancestor of the term extracted

# drop_duplicates() - we only want unique 

AACT_cond_mesh = aact_sql_extract[['nct_id','drug_mesh','cond_mesh','mesh_type']].drop_duplicates()
AACT_cond_mesh
# Out:
#            nct_id   drug_mesh                    cond_mesh      mesh_type
# 0     NCT04860141  Gabapentin          Sensation Disorders      mesh-list
# 1     NCT04860141  Gabapentin          Pain, Postoperative      mesh-list
# 2     NCT04860141  Gabapentin  Postoperative Complications  mesh-ancestor
# 3     NCT04860141  Gabapentin         Pathologic Processes  mesh-ancestor
# 4     NCT04860141  Gabapentin                         Pain  mesh-ancestor
# ...           ...         ...                          ...            ...
# 6401  NCT05024825  Gabapentin          Pain, Postoperative      mesh-list
# 6402  NCT05024825  Gabapentin  Postoperative Complications  mesh-ancestor
# 6403  NCT05024825  Gabapentin         Pathologic Processes  mesh-ancestor
# 6404  NCT05024825  Gabapentin                         Pain  mesh-ancestor
# 6405  NCT05024825  Gabapentin    Neurologic Manifestations  mesh-ancestor
#
# [2083 rows x 4 columns]

# %%
# Reorganize so that we only have each condition once, and its associated mesh types, and a list of all trials
# Rework this: we can priortize mesh_list 
# If something is a mesh_list for any trial, it is a possible direct treat relationship
# If something is a mesh_ancestor and never occurs as a mesh_list, it is only for HIERARCHICAL TRAVERSAL purposes
# so we don't need to know when things map to both 
AACT_conditions = AACT_cond_mesh.groupby(['cond_mesh','mesh_type'])['nct_id'].apply(list)
AACT_conditions
# Out:
# cond_mesh              mesh_type
# Abortion, Spontaneous  mesh-list                                            [NCT02725710]
# Acute Pain             mesh-list        [NCT02926573, NCT02703259, NCT02957097, NCT028...
# Adenocarcinoma         mesh-ancestor                           [NCT01236053, NCT01138124]
# Agnosia                mesh-list                                            [NCT01966172]
# Alcohol Drinking       mesh-list                               [NCT03274167, NCT02252536]
#                                                               ...
# Vulvar Diseases        mesh-ancestor                           [NCT00390013, NCT01301001]
# Vulvodynia             mesh-list                               [NCT00390013, NCT01301001]
# Weight Loss            mesh-list                                            [NCT04613024]
# Wounds and Injuries    mesh-ancestor    [NCT04285281, NCT04068506, NCT04025203, NCT038...
#                        mesh-list                  [NCT04705480, NCT03472469, NCT03255330]
# Name: nct_id, Length: 428, dtype: object

# %%
AACT_conditions = AACT_conditions.reset_index().sort_values(by='cond_mesh')
AACT_conditions
# Out:
#                  cond_mesh      mesh_type  \
# 0    Abortion, Spontaneous      mesh-list
# 1               Acute Pain      mesh-list
# 2           Adenocarcinoma  mesh-ancestor
# 3                  Agnosia      mesh-list
# 4         Alcohol Drinking      mesh-list
# ..                     ...            ...
# 423        Vulvar Diseases  mesh-ancestor
# 424             Vulvodynia      mesh-list
# 425            Weight Loss      mesh-list
# 426    Wounds and Injuries  mesh-ancestor
# 427    Wounds and Injuries      mesh-list
#
#                                                 nct_id
# 0                                        [NCT02725710]
# 1    [NCT02926573, NCT02703259, NCT02957097, NCT028...
# 2                           [NCT01236053, NCT01138124]
# 3                                        [NCT01966172]
# 4                           [NCT03274167, NCT02252536]
# ..                                                 ...
# 423                         [NCT00390013, NCT01301001]
# 424                         [NCT00390013, NCT01301001]
# 425                                      [NCT04613024]
# 426  [NCT04285281, NCT04068506, NCT04025203, NCT038...
# 427            [NCT04705480, NCT03472469, NCT03255330]
#
# [428 rows x 3 columns]

# %% [markdown]
# ## 1d. Mapping Conditions from MeSH to SNOMED/ICD/etc.via OMOP vocabulary
# CDM Vocabulary reference: https://ohdsi.github.io/CommonDataModel/cdm54.html#Vocabulary_Tables
#
# Downloaded from Athena
# * 05:55 PM | 13-NOV-2021
# * V5.0 09-NOV-21
#
#
# * Currently for ONE MeSh term - need to generalize for all MeSH terms outputted for drug
#
# Takes one MeSH term, identifies the standard OMOP concept for that term, and uses that standard term to then pull all nonStandard terms for that MeSH term.
# * Enables traversal from MeSH --> ICD, SNOMED, etc.

# %%
# %cd OMOP_vocabulary
# Out:
# /Users/khs2138/OneDrive - cumc.columbia.edu/Symbolic_Project/OMOP_vocabulary

# %%
# Load all concepts
concept = pd.read_csv('CONCEPT.csv',delimiter='\t',skiprows=1,
                      names = ['concept_id','concept_name',
                              'domain_id','vocabulary_id','concept_class_id','standard_concept',
                              'concept_code','valid_start_date','valid_end_date','invalid_reason'],index_col=False)
concept
# Out:
# /Users/khs2138/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (5,6,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          concept_id                             concept_name domain_id  \
# 0          45756805                     Pediatric Cardiology  Provider
# 1          45756804                 Pediatric Anesthesiology  Provider
# 2          45756803  Pathology-Anatomic / Pathology-Clinical  Provider
# 3          45756802                    Pathology - Pediatric  Provider
# 4          45756801            Pathology - Molecular Genetic  Provider
# ...             ...                                      ...       ...
# 8416980    36118955                                 Isturisa      Drug
# 8416981    36124032                                 Supemtek      Drug
# 8416982    36122578                                  Axpinet      Drug
# 8416983    36122828                                 Cyclomen      Drug
# 8416984    36122353                                  200-SEL      Drug
#
#         vocabulary_id     concept_class_id standard_concept concept_code  \
# 0                ABMS  Physician Specialty                S  OMOP4821938
# 1                ABMS  Physician Specialty                S  OMOP4821939
# 2                ABMS  Physician Specialty                S  OMOP4821940
# 3                ABMS  Physician Specialty                S  OMOP4821941
# 4                ABMS  Physician Specialty                S  OMOP4821942
# ...               ...                  ...              ...          ...
# 8416980          dm+d           Brand Name              NaN  OMOP5047799
# 8416981          dm+d           Brand Name              NaN  OMOP5047800
# 8416982          dm+d           Brand Name              NaN  OMOP5047801
# 8416983          dm+d           Brand Name              NaN  OMOP5047802
# 8416984          dm+d           Brand Name              NaN  OMOP5047803
#
#          valid_start_date  valid_end_date invalid_reason
# 0                19700101        20991231            NaN
# 1                19700101        20991231            NaN
# 2                19700101        20991231            NaN
# 3                19700101        20991231            NaN
# 4                19700101        20991231            NaN
# ...                   ...             ...            ...
# 8416980          19700101        20991231            NaN
# 8416981          19700101        20991231            NaN
# 8416982          19700101        20991231            NaN
# 8416983          19700101        20991231            NaN
# 8416984          19700101        20991231            NaN
#
# [8416985 rows x 10 columns]

# %%
# Load all concept relationships
concept_relationship = pd.read_csv('CONCEPT_RELATIONSHIP.csv',delimiter='\t',skiprows=1,
                      names = ['concept_id_1','concept_id_2',
                              'relationship_id',
                               'valid_start_date','valid_end_date','invalid_reason'],
                           index_col=False)
concept_relationship
# Out:
#           concept_id_1  concept_id_2       relationship_id  valid_start_date  \
# 0             43141480      43141480           Mapped from          20160807
# 1             43141480      43141480               Maps to          20160807
# 2             43141483      19126920  RxNorm has dose form          20160910
# 3             43141483      43141483           Mapped from          20160807
# 4             43141483      43141483               Maps to          20160807
# ...                ...           ...                   ...               ...
# 54284669      43141472      43174690      Marketed form of          20170624
# 54284670      43141472      43201766      Marketed form of          20170824
# 54284671      43141473      43141473           Mapped from          20160807
# 54284672      43141473      43141473               Maps to          20160807
# 54284673      43141473      43163687     Has marketed form          20170624
#
#           valid_end_date  invalid_reason
# 0               20991231             NaN
# 1               20991231             NaN
# 2               20991231             NaN
# 3               20991231             NaN
# 4               20991231             NaN
# ...                  ...             ...
# 54284669        20991231             NaN
# 54284670        20991231             NaN
# 54284671        20991231             NaN
# 54284672        20991231             NaN
# 54284673        20991231             NaN
#
# [54284674 rows x 6 columns]

# %%
# Identify concept_id for MeSH term 
MeSH_concept = concept.loc[(concept['vocabulary_id']=='MeSH')&(concept['concept_name']==AACT_conditions['cond_mesh'][0])]
MeSH_conceptId = MeSH_concept.reset_index()['concept_id'][0]
display(MeSH_concept)
MeSH_conceptId
# Out:
#          concept_id           concept_name  domain_id vocabulary_id  \
# 1719985    45613996  Abortion, Spontaneous  Condition          MeSH
#
#         concept_class_id standard_concept concept_code  valid_start_date  \
# 1719985     Main Heading              NaN      D000022          19700101
#
#          valid_end_date invalid_reason
# 1719985        20991231            NaN
# 45613996

# %%
# Get the entry in the CONCEPT_RELATIONSHIP table for that MeSH term
MeSH_rel_entry = concept_relationship.loc[concept_relationship['concept_id_1']==MeSH_conceptId].reset_index() # NonStandard --> Standard
display(MeSH_rel_entry)

# Get the SNOMED standard ID 
standard_id = MeSH_rel_entry['concept_id_2'][0]
standard_id
# Out:
#      index  concept_id_1  concept_id_2 relationship_id  valid_start_date  \
# 0  6771407      45613996       4067106         Maps to          20131007
#
#    valid_end_date  invalid_reason
# 0        20991231             NaN
# 4067106

# %%
# Get all NonStandard conceptIDs from relationship tables for that SNOMED ID 
NonStandard_Concepts = concept_relationship.loc[(concept_relationship['concept_id_1']==standard_id)&(concept_relationship['relationship_id']=='Mapped from')]  # Get all NonStandard concept IDs
NonStandard_Concepts
# Out:
#           concept_id_1  concept_id_2 relationship_id  valid_start_date  \
# 1535268        4067106       3519999     Mapped from          20200731
# 1535269        4067106       3534301     Mapped from          20200731
# 1535270        4067106       3534302     Mapped from          20200731
# 1535371        4067106       3536059     Mapped from          20200731
# 1535460        4067106       3537760     Mapped from          20200731
# ...                ...           ...             ...               ...
# 42984233       4067106      45430318     Mapped from          20140401
# 42984234       4067106      45436935     Mapped from          20140401
# 42984235       4067106      45463679     Mapped from          19700101
# 42984236       4067106      45500254     Mapped from          20140401
# 42984237       4067106      45592170     Mapped from          20140701
#
#           valid_end_date  invalid_reason
# 1535268         20991231             NaN
# 1535269         20991231             NaN
# 1535270         20991231             NaN
# 1535371         20991231             NaN
# 1535460         20991231             NaN
# ...                  ...             ...
# 42984233        20991231             NaN
# 42984234        20991231             NaN
# 42984235        20991231             NaN
# 42984236        20991231             NaN
# 42984237        20991231             NaN
#
# [134 rows x 6 columns]

# %%
# Join nonstandard conceptIDs with OMOP concept table to get data on the concept name, vocabualry source, standard/non, etc. 
merge_concepts_rels = pd.merge(NonStandard_Concepts, concept,
                        how="left", left_on='concept_id_2', right_on='concept_id')
merge_concepts_rels
# Out:
#      concept_id_1  concept_id_2 relationship_id  valid_start_date_x  \
# 0         4067106       3519999     Mapped from            20200731
# 1         4067106       3534301     Mapped from            20200731
# 2         4067106       3534302     Mapped from            20200731
# 3         4067106       3536059     Mapped from            20200731
# 4         4067106       3537760     Mapped from            20200731
# ..            ...           ...             ...                 ...
# 129       4067106      45430318     Mapped from            20140401
# 130       4067106      45436935     Mapped from            20140401
# 131       4067106      45463679     Mapped from            19700101
# 132       4067106      45500254     Mapped from            20140401
# 133       4067106      45592170     Mapped from            20140701
#
#      valid_end_date_x  invalid_reason_x  concept_id  \
# 0            20991231               NaN     3519999
# 1            20991231               NaN     3534301
# 2            20991231               NaN     3534302
# 3            20991231               NaN     3536059
# 4            20991231               NaN     3537760
# ..                ...               ...         ...
# 129          20991231               NaN    45430318
# 130          20991231               NaN    45436935
# 131          20991231               NaN    45463679
# 132          20991231               NaN    45500254
# 133          20991231               NaN    45592170
#
#                                           concept_name  domain_id  \
# 0    Unspecified abortion with genital tract or pel...  Condition
# 1         Unspecified abortion with metabolic disorder  Condition
# 2              Unspecified abortion with renal failure  Condition
# 3    Unspecified abortion with delayed or excessive...  Condition
# 4                      Unspecified abortion with shock  Condition
# ..                                                 ...        ...
# 129       Unspecified abortion with metabolic disorder  Condition
# 130           Other abnormal product of conception NOS  Condition
# 131                                        Miscarriage  Condition
# 132        Unspecified spontaneous abortion with shock  Condition
# 133                               Spontaneous abortion  Condition
#
#     vocabulary_id  concept_class_id standard_concept     concept_code  \
# 0          SNOMED  Clinical Finding              NaN  587061000000104
# 1          SNOMED  Clinical Finding              NaN  587071000000106
# 2          SNOMED  Clinical Finding              NaN  587081000000108
# 3          SNOMED  Clinical Finding              NaN  614961000000101
# 4          SNOMED  Clinical Finding              NaN  639881000000106
# ..            ...               ...              ...              ...
# 129          Read              Read              NaN          L070400
# 130          Read              Read              NaN          L01z.00
# 131          Read              Read              NaN          L04..11
# 132          Read              Read              NaN          L040500
# 133         ICD10   ICD10 Hierarchy              NaN              O03
#
#      valid_start_date_y  valid_end_date_y invalid_reason_y
# 0              20100401          20110401                U
# 1              20100401          20121001                U
# 2              20100401          20121001                U
# 3              20100401          20110401                U
# 4              20100401          20121001                U
# ..                  ...               ...              ...
# 129            20140401          20991231              NaN
# 130            19700101          20991231              NaN
# 131            19700101          20991231              NaN
# 132            20140401          20991231              NaN
# 133            19900501          20991231              NaN
#
# [134 rows x 16 columns]

# %%
# Pull desired columns, rename columns for clarity, and sort by vocabulary for easy reference 
concept_map = merge_concepts_rels[['concept_id_1','concept_id_2','concept_name','domain_id','vocabulary_id','concept_class_id','standard_concept','concept_code']]
concept_map =  concept_map.rename(columns = {'concept_id_1':'standard_concept_id','concept_id_':'concept_id'})
concept_map.sort_values(by='vocabulary_id')
# Out:
#      standard_concept_id  concept_id_2  \
# 107              4067106      45937965
# 73               4067106      45927052
# 42               4067106      45937856
# 26               4067106      37611702
# 133              4067106      45592170
# ..                   ...           ...
# 96               4067106       4113849
# 61               4067106       4114138
# 76               4067106       3537764
# 0                4067106       3519999
# 126              4067106      35826466
#
#                                           concept_name    domain_id  \
# 107                             Pregnancy, miscarriage    Condition
# 73                                Spontaneous abortion    Condition
# 42                           second trimester abortion    Condition
# 26                                Spontaneous abortion    Condition
# 133                               Spontaneous abortion    Condition
# ..                                                 ...          ...
# 96   Unspecified spontaneous abortion with other sp...    Condition
# 61   Unspecified abortion with genital tract or pel...    Condition
# 76                            Unspecified abortion NOS    Condition
# 0    Unspecified abortion with genital tract or pel...    Condition
# 126                                        miscarriage  Observation
#
#     vocabulary_id  concept_class_id standard_concept     concept_code
# 107          CIEL         Diagnosis              NaN               48
# 73           CIEL         Diagnosis              NaN           126127
# 42           CIEL         Diagnosis              NaN           158735
# 26          CIM10   ICD10 Hierarchy              NaN              O03
# 133         ICD10   ICD10 Hierarchy              NaN              O03
# ..            ...               ...              ...              ...
# 96         SNOMED  Clinical Finding              NaN        198640005
# 61         SNOMED  Clinical Finding              NaN        198770005
# 76         SNOMED  Clinical Finding              NaN  639931000000103
# 0          SNOMED  Clinical Finding              NaN  587061000000104
# 126    UK Biobank             Value              NaN           6-1559
#
# [134 rows x 8 columns]

# %% [markdown]
# # 2. DrugCentral
# DrugCentral is online drug information resource created and maintained by Division of Translational Informatics at University of New Mexico in collaboration with the IDG.
#
#
# DrugCentral provides information on active ingredients chemical entities, pharmaceutical products, drug mode of action, indications, pharmacologic action. We monitor FDA, EMA, and PMDA for new drug approval on regular basis to ensure currency of the resource. Limited information on discontinued and drugs approved outside US is also available however regulatory approval information can't be verified. Database developed and maintained by Oleg Ursu and Tudor Oprea. Web application developed by Jayme Holmes.
#
# https://drugcentral.org/download
#
# **Utility for project**:
# * Data on indication, off-label drug use
# * Active ingredient data
# * Contians OMOP data linked with FDA data, ingredient, etc.

# %% [markdown]
# ### 2a. Connect to Database

# %%
dsn_DC = ("host='unmtid-dbs.net' port='5433' dbname='drugcentral' user='drugman' password='dosage'")
dbcon_DC = psycopg2.connect(dsn_DC)
dbcon_DC.cursor_factory = psycopg2.extras.DictCursor
dbcon_DC
# Out:
# <connection object at 0x7fb9a18d8eb0; dsn: 'user=drugman password=xxx dbname=drugcentral host=unmtid-dbs.net port=5433', closed: 0>

# %%
# Check Version
sql=(f"SELECT * FROM public.dbversion")
logging.debug(f"SQL: {sql}")
df = read_sql_query(sql, dbcon_DC)
df
# Out:
#    version                   dtime
# 0       49 2021-09-24 09:24:23.962

# %% [markdown]
# ## 2b. Extract Indications
# Leveraging:
# * Drug Central public.omop
# * Drug Central public.structure

# %%
# Pull ALL indications from OMOP table, map to drug name using strucutre table from Drug Central
sql = """\
SELECT 
	omop.struct_id, 
    omop.concept_id as omop_concept_id, 
    omop.relationship_name, 
    omop.concept_name as omop_concept_name, 
    omop.umls_cui, 
    omop.cui_semantic_type as umls_semantic_type,
    omop.snomed_conceptid,
    omop.snomed_full_name,
    struct.name as drug_name
from public.omop_relationship omop
JOIN
	public.structures struct 
ON omop.struct_id = struct.id
"""
logging.debug(f"SQL: {sql}")
omop_struct_sql_extract= read_sql_query(sql, dbcon_DC)
omop_struct_sql_extract
# Out:
#        struct_id  omop_concept_id relationship_name  \
# 0           5391         40249429        indication
# 1           5392         40249397        indication
# 2           5393         40249397        indication
# 3           5393         40248953        indication
# 4           5394         21004733        indication
# ...          ...              ...               ...
# 41425       1982         21003217     off-label use
# 41426       1982         40249519     off-label use
# 41427       1982         40249520     off-label use
# 41428       4209         40249521     off-label use
# 41429       2475         40249522     off-label use
#
#                            omop_concept_name  umls_cui umls_semantic_type  \
# 0           Triple negative breast neoplasms  C3539878               T191
# 1      Metastatic non-small cell lung cancer  C0278987               T191
# 2      Metastatic non-small cell lung cancer  C0278987               T191
# 3                Medullary thyroid carcinoma  C0238462               T191
# 4             Gastrointestinal stromal tumor  C0238198               T191
# ...                                      ...       ...                ...
# 41425                    Nausea and vomiting  C0027498               T184
# 41426               cannabinoid hyperememsis  C4511590               T047
# 41427               cannabinoid hyperememsis  C4511594               T047
# 41428                PTSD related nightmares  C1997862               T048
# 41429                                   Acne  C0702166               T047
#
#        snomed_conceptid                                   snomed_full_name  \
# 0          7.069700e+08                   Triple negative breast neoplasms
# 1                   NaN              Metastatic non-small cell lung cancer
# 2                   NaN              Metastatic non-small cell lung cancer
# 3          2.550320e+08                        Medullary thyroid carcinoma
# 4          4.201200e+08                     Gastrointestinal stromal tumor
# ...                 ...                                                ...
# 41425      1.693200e+07                                Nausea and vomiting
# 41426      1.104788e+16  Cannabis hyperemesis syndrome co-occurrent and...
# 41427      1.104801e+16  Cannabis hyperemesis syndrome co-occurrent and...
# 41428      4.286870e+08  Nightmares associated with chronic post-trauma...
# 41429      1.138100e+07                                               Acne
#
#                    drug_name
# 0      sacituzumab govitecan
# 1                 capmatinib
# 2              selpercatinib
# 3              selpercatinib
# 4                 ripretinib
# ...                      ...
# 41425             olanzapine
# 41426             olanzapine
# 41427             olanzapine
# 41428               prazosin
# 41429         spironolactone
#
# [41430 rows x 9 columns]

# %% [markdown]
# ### 2c. Extract indications for drug of choice

# %%
# Extract specifically for gabapentin
omop_indications = omop_struct_sql_extract.loc[omop_struct_sql_extract['drug_name']=='gabapentin'].sort_values(by='relationship_name').reset_index(drop=True)
omop_indications

## Disregard contraindication
# Out:
#     struct_id  omop_concept_id relationship_name  \
# 0        1264         21001022  contraindication
# 1        1264         21000985  contraindication
# 2        1264         21002292  contraindication
# 3        1264         21000166        indication
# 4        1264         21004851        indication
# 5        1264         21013508        indication
# 6        1264         21002508     off-label use
# 7        1264         21003090     off-label use
# 8        1264         40249515     off-label use
# 9        1264          4264789     off-label use
# 10       1264         21002865     off-label use
# 11       1264         21003063     off-label use
# 12       1264         40249494     off-label use
# 13       1264         21000996     off-label use
# 14       1264         40249488     off-label use
# 15       1264         40249516     off-label use
# 16       1264         21013795     off-label use
# 17       1264         21003081     off-label use
# 18       1264         21013872     off-label use
# 19       1264         21004236     off-label use
# 20       1264         40249517     off-label use
#
#                      omop_concept_name  umls_cui umls_semantic_type  \
# 0                  Depressive disorder  C0011581               T048
# 1                    Suicidal thoughts  C0424000               T033
# 2                       Kidney disease  C0022658               T047
# 3               Postherpetic neuralgia  C0032768               T047
# 4                        Restless legs  C0035258               T047
# 5   Partial Epilepsy Treatment Adjunct      None               None
# 6                  Menopausal flushing  C0600142               T184
# 7                         Chronic pain  C0150055               T184
# 8                  Refractory pruritis  C0033774               T184
# 9                     Anxiety disorder  C0003469               T048
# 10                        Fibromyalgia  C0016053               T047
# 11                            Insomnia  C0917801               T184
# 12                    Chronic pruritus  C0033774               T184
# 13                Alcohol use disorder  C0001973               T048
# 14                       Chronic cough  C0010201               T184
# 15                  Post-stroke nausea  C0027497               T184
# 16                    Neuropathic pain  C0027796               T184
# 17            Acute postoperative pain  C2215257               T184
# 18                    Essential tremor  C3543433               T047
# 19                 Intractable hiccups  C0744898               T047
# 20             Menopausal night sweats  C0028081               T184
#
#     snomed_conceptid          snomed_full_name   drug_name
# 0       3.548901e+07       Depressive disorder  gabapentin
# 1       6.471006e+06         Suicidal thoughts  gabapentin
# 2       9.070800e+07            Kidney disease  gabapentin
# 3       2.177002e+06    Postherpetic neuralgia  gabapentin
# 4       3.291401e+07             Restless legs  gabapentin
# 5                NaN                      None  gabapentin
# 6       1.984360e+08       Menopausal flushing  gabapentin
# 7       8.242300e+07              Chronic pain  gabapentin
# 8       4.183630e+08           Itching of skin  gabapentin
# 9       1.974800e+08          Anxiety disorder  gabapentin
# 10      2.030820e+08              Fibromyalgia  gabapentin
# 11      1.934620e+08                  Insomnia  gabapentin
# 12      4.183630e+08           Itching of skin  gabapentin
# 13      7.200002e+06                Alcoholism  gabapentin
# 14      6.815401e+07             Chronic cough  gabapentin
# 15      4.225870e+08                    Nausea  gabapentin
# 16      2.473980e+08          Neuropathic pain  gabapentin
# 17      1.074010e+14  Acute postoperative pain  gabapentin
# 18      6.095580e+08          Essential tremor  gabapentin
# 19      7.167710e+08           Chronic hiccups  gabapentin
# 20      4.298400e+07              Night sweats  gabapentin

# %% [markdown]
# ### Reformat
# 1. SNOMED_CONCEPT_ID from drug central is actually the SNOMED_concept_code
# * We want to match on concept_ID, to traverse through OMOP
# 2. Reformat concept_ID column as int

# %%
# Convert SNOMED CONCEPT_ID (really: CONCEPT_CODE) to int
omop_indications['snomed_conceptid'] = omop_indications['snomed_conceptid'].fillna(0).astype(np.int64) 

# Join nonstandard conceptIDs with OMOP concept table to get data on the concept name, vocabualry source, standard flag, etc. 
merge_DC = pd.merge(omop_indications, concept, 
                    how="left", left_on='snomed_conceptid', right_on='concept_code')
merge_DC = merge_DC.loc[merge_DC['vocabulary_id']!='Nebraska Lexicon'].reset_index()
merge_DC

DC_indications = merge_DC[['struct_id','omop_concept_id','omop_concept_name','relationship_name','umls_cui','umls_semantic_type','concept_id','snomed_conceptid','snomed_full_name','drug_name','concept_class_id','standard_concept']]
DC_indications =  DC_indications.rename(columns = {'snomed_conceptid':'snomed_concept_code','concept_id':'snomed_concept_id'})
DC_indications['snomed_concept_id'] = DC_indications['snomed_concept_id'].fillna(0).astype(np.int64)
DC_indications
# Out:
#     struct_id  omop_concept_id                   omop_concept_name  \
# 0        1264         21001022                 Depressive disorder
# 1        1264         21000985                   Suicidal thoughts
# 2        1264         21002292                      Kidney disease
# 3        1264         21000166              Postherpetic neuralgia
# 4        1264         21004851                       Restless legs
# 5        1264         21013508  Partial Epilepsy Treatment Adjunct
# 6        1264         21002508                 Menopausal flushing
# 7        1264         21003090                        Chronic pain
# 8        1264         40249515                 Refractory pruritis
# 9        1264          4264789                    Anxiety disorder
# 10       1264         21002865                        Fibromyalgia
# 11       1264         21003063                            Insomnia
# 12       1264         40249494                    Chronic pruritus
# 13       1264         21000996                Alcohol use disorder
# 14       1264         40249488                       Chronic cough
# 15       1264         40249516                  Post-stroke nausea
# 16       1264         21013795                    Neuropathic pain
# 17       1264         21003081            Acute postoperative pain
# 18       1264         21013872                    Essential tremor
# 19       1264         21004236                 Intractable hiccups
# 20       1264         40249517             Menopausal night sweats
#
#    relationship_name  umls_cui umls_semantic_type  snomed_concept_id  \
# 0   contraindication  C0011581               T048             440383
# 1   contraindication  C0424000               T033            4273391
# 2   contraindication  C0022658               T047             198124
# 3         indication  C0032768               T047            4071164
# 4         indication  C0035258               T047              73754
# 5         indication      None               None                  0
# 6      off-label use  C0600142               T184            4113666
# 7      off-label use  C0150055               T184             436096
# 8      off-label use  C0033774               T184            4169287
# 9      off-label use  C0003469               T048             442077
# 10     off-label use  C0016053               T047           40405599
# 11     off-label use  C0917801               T184             436962
# 12     off-label use  C0033774               T184            4169287
# 13     off-label use  C0001973               T048            4218106
# 14     off-label use  C0010201               T184            4195384
# 15     off-label use  C0027497               T184              31967
# 16     off-label use  C0027796               T184            4090564
# 17     off-label use  C2215257               T184           43530621
# 18     off-label use  C3543433               T047           43531003
# 19     off-label use  C0744898               T047           37396824
# 20     off-label use  C0028081               T184            4181178
#
#    snomed_concept_code          snomed_full_name   drug_name  \
# 0             35489007       Depressive disorder  gabapentin
# 1              6471006         Suicidal thoughts  gabapentin
# 2             90708001            Kidney disease  gabapentin
# 3              2177002    Postherpetic neuralgia  gabapentin
# 4             32914008             Restless legs  gabapentin
# 5                    0                      None  gabapentin
# 6            198436008       Menopausal flushing  gabapentin
# 7             82423001              Chronic pain  gabapentin
# 8            418363000           Itching of skin  gabapentin
# 9            197480006          Anxiety disorder  gabapentin
# 10           203082005              Fibromyalgia  gabapentin
# 11           193462001                  Insomnia  gabapentin
# 12           418363000           Itching of skin  gabapentin
# 13             7200002                Alcoholism  gabapentin
# 14            68154008             Chronic cough  gabapentin
# 15           422587007                    Nausea  gabapentin
# 16           247398009          Neuropathic pain  gabapentin
# 17     107401000119105  Acute postoperative pain  gabapentin
# 18           609558009          Essential tremor  gabapentin
# 19           716771000           Chronic hiccups  gabapentin
# 20            42984000              Night sweats  gabapentin
#
#     concept_class_id standard_concept
# 0   Clinical Finding                S
# 1   Clinical Finding                S
# 2   Clinical Finding                S
# 3   Clinical Finding                S
# 4   Clinical Finding                S
# 5                NaN              NaN
# 6   Clinical Finding                S
# 7   Clinical Finding                S
# 8   Clinical Finding                S
# 9   Clinical Finding                S
# 10  Clinical Finding                S
# 11  Clinical Finding                S
# 12  Clinical Finding                S
# 13  Clinical Finding                S
# 14  Clinical Finding                S
# 15  Clinical Finding                S
# 16  Clinical Finding                S
# 17  Clinical Finding                S
# 18  Clinical Finding                S
# 19  Clinical Finding                S
# 20  Clinical Finding                S

# %%
DC_indications.to_csv('Gabapentin_indications_drugcentral.csv')

# %% [markdown]
# ## 2d. Mapping Conditions from OMOP/SNOMED to ICD/etc. via OMOP vocabulary

# %%
# Get the SNOMED standard name 
standard_name_DC = omop_indications['snomed_full_name'][0]
standard_name_DC
# Out:
# 'Depressive disorder'

# %%
# Get the SNOMED standard concept_ID from the concept_name using concept table
standard_id_DC = concept.loc[(concept['concept_name']==standard_name_DC)&(concept['standard_concept']=='S')]['concept_id'].reset_index(drop=True)
standard_id_DC = standard_id_DC[0]
standard_id_DC
# Out:
# 440383

# %%
# Get all NonStandard conceptIDs from relationship tables for that SNOMED ID 
NonStandard_Concepts_DC = concept_relationship.loc[(concept_relationship['concept_id_1']==standard_id_DC)&(concept_relationship['relationship_id']=='Mapped from')]  # Get all NonStandard concept IDs
NonStandard_Concepts_DC
# Out:
#           concept_id_1  concept_id_2 relationship_id  valid_start_date  \
# 14561603        440383       3528972     Mapped from          20200731
# 14664354        440383       1410661     Mapped from          20160101
# 14664355        440383       1410662     Mapped from          20160101
# 14664356        440383       3122804     Mapped from          19700101
# 14664357        440383       3132802     Mapped from          19700101
# ...                ...           ...             ...               ...
# 51198864        440383      45446561     Mapped from          20150917
# 51198865        440383      45463353     Mapped from          20140401
# 51198866        440383      45473438     Mapped from          20150917
# 51198867        440383      45523245     Mapped from          20150917
# 51198868        440383      45595904     Mapped from          20161201
#
#           valid_end_date  invalid_reason
# 14561603        20991231             NaN
# 14664354        20991231             NaN
# 14664355        20991231             NaN
# 14664356        20991231             NaN
# 14664357        20991231             NaN
# ...                  ...             ...
# 51198864        20991231             NaN
# 51198865        20991231             NaN
# 51198866        20991231             NaN
# 51198867        20991231             NaN
# 51198868        20991231             NaN
#
# [95 rows x 6 columns]

# %%
# Join nonstandard conceptIDs with OMOP concept table to get data on the concept name, vocabualry source, standard/non, etc. 
merge_concepts_rels_DC = pd.merge(NonStandard_Concepts_DC, concept,
                        how="left", left_on='concept_id_2', right_on='concept_id')
merge_concepts_rels_DC
# Out:
#     concept_id_1  concept_id_2 relationship_id  valid_start_date_x  \
# 0         440383       3528972     Mapped from            20200731
# 1         440383       1410661     Mapped from            20160101
# 2         440383       1410662     Mapped from            20160101
# 3         440383       3122804     Mapped from            19700101
# 4         440383       3132802     Mapped from            19700101
# ..           ...           ...             ...                 ...
# 90        440383      45446561     Mapped from            20150917
# 91        440383      45463353     Mapped from            20140401
# 92        440383      45473438     Mapped from            20150917
# 93        440383      45523245     Mapped from            20150917
# 94        440383      45595904     Mapped from            20161201
#
#     valid_end_date_x  invalid_reason_x  concept_id  \
# 0           20991231               NaN     3528972
# 1           20991231               NaN     1410661
# 2           20991231               NaN     1410662
# 3           20991231               NaN     3122804
# 4           20991231               NaN     3132802
# ..               ...               ...         ...
# 90          20991231               NaN    45446561
# 91          20991231               NaN    45463353
# 92          20991231               NaN    45473438
# 93          20991231               NaN    45523245
# 94          20991231               NaN    45595904
#
#                                          concept_name  domain_id  \
# 0   [X] Depression: [other episodes] or [atypical]...  Condition
# 1                     Depressive episode, unspecified  Condition
# 2                    Depression (machine translation)  Condition
# 3                             Depressive disorder NEC  Condition
# 4               Mood disorder with depressive feature  Condition
# ..                                                ...        ...
# 90                              [X]Depressive episode  Condition
# 91                        [X]Monopolar depression NOS  Condition
# 92                         [X]Depressive disorder NOS  Condition
# 93                       [X]Other depressive episodes  Condition
# 94                                 Depressive episode  Condition
#
#        vocabulary_id  concept_class_id standard_concept     concept_code  \
# 0             SNOMED  Clinical Finding              NaN  419311000000100
# 1            ICD10CN        ICD10 code              NaN          F32.900
# 2            ICD10CN        ICD10 code              NaN          F32.901
# 3   Nebraska Lexicon  Clinical Finding              NaN        192078003
# 4   Nebraska Lexicon  Clinical Finding              NaN   21061000119107
# ..               ...               ...              ...              ...
# 90              Read              Read              NaN          Eu32.00
# 91              Read              Read              NaN          Eu33z11
# 92              Read              Read              NaN          Eu32z12
# 93              Read              Read              NaN          Eu32y00
# 94             ICD10   ICD10 Hierarchy              NaN              F32
#
#     valid_start_date_y  valid_end_date_y invalid_reason_y
# 0             19700101          20090401                U
# 1             20160101          20991231              NaN
# 2             20160101          20991231              NaN
# 3             20020130          20020131                U
# 4             20170131          20170731                U
# ..                 ...               ...              ...
# 90            19700101          20991231              NaN
# 91            19700101          20991231              NaN
# 92            19700101          20991231              NaN
# 93            19700101          20991231              NaN
# 94            19900501          20991231              NaN
#
# [95 rows x 16 columns]

# %%
# Pull desired columns, rename columns for clarity, and sort by vocabulary for easy reference 
concept_map_DC = merge_concepts_rels_DC[['concept_id_1','concept_id_2','concept_name','domain_id','vocabulary_id','concept_class_id','standard_concept','concept_code']]
concept_map_DC =  concept_map_DC.rename(columns = {'concept_id_1':'standard_concept_id','concept_id_2':'concept_id'}).sort_values(by='vocabulary_id')
pd.set_option('display.max_rows', concept_map_DC.shape[0]+1)
concept_map_DC
# Out:
#     standard_concept_id  concept_id  \
# 47               440383    45919614
# 27               440383    45913939
# 28               440383    45920960
# 29               440383    45922522
# 65               440383    45908377
# 77               440383    37604841
# 76               440383    37604779
# 75               440383    37604748
# 74               440383    37604747
# 73               440383    37604686
# 72               440383    37604662
# 60               440383    37605308
# 59               440383    37605176
# 36               440383    37604665
# 37               440383    37604670
# 38               440383    37604842
# 39               440383    37604874
# 58               440383    37604873
# 57               440383    37604855
# 78               440383    37604856
# 79               440383    37604857
# 80               440383    37604875
# 20               440383    37614464
# 84               440383    37614463
# 83               440383    37605298
# 82               440383    37605175
# 81               440383    37604879
# 5                440383    37604696
# 6                440383    37604714
# 7                440383    37604715
# 8                440383    37604716
# 9                440383    37604749
# 10               440383    37604778
# 11               440383    37604780
# 12               440383    37604880
# 13               440383    37604881
# 14               440383    37604888
# 15               440383    37604889
# 16               440383    37604890
# 17               440383    37605174
# 18               440383    37605303
# 19               440383    37612484
# 56               440383    37604843
# 55               440383    37604691
# 94               440383    45595904
# 44               440383    45571760
# 43               440383    45571759
# 35               440383    37200320
# 52               440383    35207154
# 69               440383     1410660
# 68               440383     1410659
# 67               440383     1410658
# 50               440383     1410663
# 49               440383     1410657
# 48               440383     1410656
# 2                440383     1410662
# 1                440383     1410661
# 30               440383     1410646
# 71               440383    37082800
# 34               440383    37082805
# 54               440383    37082806
# 63               440383    44833421
# 41               440383    42486687
# 40               440383    42486682
# 61               440383    42486688
# 45               440383    45614157
# 46               440383    45617789
# 70               440383     3105337
# 32               440383     3237831
# 31               440383     3146674
# 3                440383     3122804
# 4                440383     3132802
# 26               440383    45524869
# 64               440383    45456581
# 92               440383    45473438
# 91               440383    45463353
# 90               440383    45446561
# 93               440383    45523245
# 25               440383    45503243
# 24               440383    45493337
# 23               440383    45473437
# 66               440383      440383
# 88               440383    44797412
# 89               440383    44798442
# 87               440383    44797200
# 86               440383    44794775
# 21               440383    40322275
# 33               440383     4141235
# 22               440383    44796370
# 51               440383     4103573
# 42               440383    44796936
# 62               440383    44800512
# 85               440383    44782706
# 0                440383     3528972
# 53               440383    35825865
#
#                                          concept_name    domain_id  \
# 47                                 DEPRESSIVE EPISODE    Condition
# 27                                        Melancholia    Condition
# 28                                Depressive Disorder    Condition
# 29                                 DEPRESSIVE EPISODE    Condition
# 65                                         Depression    Condition
# 77  subcortical vascular dementia with other sympt...    Condition
# 76  Dementia disease due to HIV [HIV], with other ...    Condition
# 75  Dementia in Huntington's disease, with other s...    Condition
# 74  Dementia in Huntington's disease, with other s...    Condition
# 73  Dementia in Pick's disease, with other symptom...    Condition
# 72  Acute onset vascular dementia with other sympt...    Condition
# 60  Dementia in other diseases classified elsewher...    Condition
# 59  mixed vascular dementia, cortical and subcorti...    Condition
# 36  subcortical vascular dementia with other sympt...    Condition
# 37  mixed vascular dementia, cortical and subcorti...    Condition
# 38  subcortical vascular dementia with other sympt...    Condition
# 39  Dementia in Creutzfeldt-Jakob disease, with ot...    Condition
# 58  Dementia in Creutzfeldt-Jakob disease, with ot...    Condition
# 57  Dementia in Pick's disease, with other symptom...    Condition
# 78  Dementia in Pick's disease, with other symptom...    Condition
# 79  Dementia in Pick's disease, with other symptom...    Condition
# 80  Dementia in Creutzfeldt-Jakob disease, with ot...    Condition
# 20                    Depressive episode, unspecified    Condition
# 84                          Other depressive episodes    Condition
# 83  Dementia in Parkinson's disease, with other sy...    Condition
# 82  mixed vascular dementia, cortical and subcorti...    Condition
# 81  Dementia in other diseases classified elsewher...    Condition
# 5   Dementia in Huntington's disease, with other s...    Condition
# 6   Dementia in Parkinson's disease, with other sy...    Condition
# 7   Dementia in Parkinson's disease, with other sy...    Condition
# 8   Dementia in Parkinson's disease, with other sy...    Condition
# 9   Dementia in Huntington's disease, with other s...    Condition
# 10  Dementia disease due to HIV [HIV], with other ...    Condition
# 11  Dementia disease due to HIV [HIV], with other ...    Condition
# 12  Dementia in other diseases classified elsewher...    Condition
# 13  Dementia in other diseases classified elsewher...    Condition
# 14  Acute onset vascular dementia with other sympt...    Condition
# 15  Acute onset vascular dementia with other sympt...    Condition
# 16  Acute onset vascular dementia with other sympt...    Condition
# 17  mixed vascular dementia, cortical and subcorti...    Condition
# 18  Dementia disease due to HIV [HIV], with other ...    Condition
# 19                                 Depressive episode    Condition
# 56  subcortical vascular dementia with other sympt...    Condition
# 55  Dementia in Creutzfeldt-Jakob disease, with ot...    Condition
# 94                                 Depressive episode    Condition
# 44                    Depressive episode, unspecified    Condition
# 43                          Other depressive episodes    Condition
# 35                Other specified depressive episodes    Condition
# 52                          Other depressive episodes    Condition
# 69                    Depressive episode, unspecified    Condition
# 68          Atypical depression (machine translation)    Condition
# 67         Menopause depression (machine translation)    Condition
# 50          Reactive depression (machine translation)    Condition
# 49                          Other depressive episodes    Condition
# 48                          Other depressive episodes    Condition
# 2                    Depression (machine translation)    Condition
# 1                     Depressive episode, unspecified    Condition
# 30                                 Depressive episode    Condition
# 71                                 Depressive episode    Condition
# 34                          Other depressive episodes    Condition
# 54                    Depressive episode, unspecified    Condition
# 63      Depressive disorder, not elsewhere classified    Condition
# 41                          Other depressive episodes    Condition
# 40                                 Depressive episode    Condition
# 61                    Depressive episode, unspecified    Condition
# 45                                         Depression         Drug
# 46                                Depressive Disorder    Condition
# 70                                     Depression NOS    Condition
# 32                    Mood disorder of depressed type    Condition
# 31                                     Depression NOS    Condition
# 3                             Depressive disorder NEC    Condition
# 4               Mood disorder with depressive feature    Condition
# 26                                         DEPRESSION    Condition
# 64                 [X]Depressive episode, unspecified    Condition
# 92                         [X]Depressive disorder NOS    Condition
# 91                        [X]Monopolar depression NOS    Condition
# 90                              [X]Depressive episode    Condition
# 93                       [X]Other depressive episodes    Condition
# 25                               Depressive psychoses    Condition
# 24                            Depressive disorder NEC    Condition
# 23                                  [X]Depression NOS    Condition
# 66                                Depressive disorder    Condition
# 88                 [X]Depressive episode, unspecified    Condition
# 89  [X]Recurrent depressive disorder, current epis...    Condition
# 87  [X]Recurrent depressive disorder, currently in...    Condition
# 86  [X]Recurrent depressive disorder, current epis...    Condition
# 21                                     Depression NOS    Condition
# 33                                     Depression NOS    Condition
# 22                       [X]Other depressive episodes    Condition
# 51                            Depressive disorder NEC    Condition
# 42            [X]Other recurrent depressive disorders    Condition
# 62      [X]Recurrent depressive disorder, unspecified    Condition
# 85                    Mood disorder of depressed type    Condition
# 0   [X] Depression: [other episodes] or [atypical]...    Condition
# 53                                         depression  Observation
#
#        vocabulary_id     concept_class_id standard_concept     concept_code
# 47              CIEL            Diagnosis              NaN              207
# 27              CIEL            Diagnosis              NaN           119535
# 28              CIEL            Diagnosis              NaN           142563
# 29              CIEL            Diagnosis              NaN              911
# 65              CIEL            Diagnosis              NaN           119537
# 77             CIM10           ICD10 code              NaN          F01.230
# 76             CIM10           ICD10 code              NaN          F02.431
# 75             CIM10           ICD10 code              NaN          F02.231
# 74             CIM10           ICD10 code              NaN          F02.230
# 73             CIM10           ICD10 code              NaN           F02.03
# 72             CIM10           ICD10 code              NaN           F01.03
# 60             CIM10           ICD10 code              NaN           F02.83
# 59             CIM10           ICD10 code              NaN          F01.332
# 36             CIM10           ICD10 code              NaN           F01.23
# 37             CIM10           ICD10 code              NaN           F01.33
# 38             CIM10           ICD10 code              NaN          F01.231
# 39             CIM10           ICD10 code              NaN          F02.131
# 58             CIM10           ICD10 code              NaN          F02.130
# 57             CIM10           ICD10 code              NaN          F02.030
# 78             CIM10           ICD10 code              NaN          F02.031
# 79             CIM10           ICD10 code              NaN          F02.032
# 80             CIM10           ICD10 code              NaN          F02.132
# 20             CIM10           ICD10 code              NaN            F32.9
# 84             CIM10           ICD10 code              NaN            F32.8
# 83             CIM10           ICD10 code              NaN           F02.33
# 82             CIM10           ICD10 code              NaN          F01.331
# 81             CIM10           ICD10 code              NaN          F02.830
# 5              CIM10           ICD10 code              NaN           F02.23
# 6              CIM10           ICD10 code              NaN          F02.330
# 7              CIM10           ICD10 code              NaN          F02.331
# 8              CIM10           ICD10 code              NaN          F02.332
# 9              CIM10           ICD10 code              NaN          F02.232
# 10             CIM10           ICD10 code              NaN          F02.430
# 11             CIM10           ICD10 code              NaN          F02.432
# 12             CIM10           ICD10 code              NaN          F02.831
# 13             CIM10           ICD10 code              NaN          F02.832
# 14             CIM10           ICD10 code              NaN          F01.030
# 15             CIM10           ICD10 code              NaN          F01.031
# 16             CIM10           ICD10 code              NaN          F01.032
# 17             CIM10           ICD10 code              NaN          F01.330
# 18             CIM10           ICD10 code              NaN           F02.43
# 19             CIM10      ICD10 Hierarchy              NaN              F32
# 56             CIM10           ICD10 code              NaN          F01.232
# 55             CIM10           ICD10 code              NaN           F02.13
# 94             ICD10      ICD10 Hierarchy              NaN              F32
# 44             ICD10           ICD10 code              NaN            F32.9
# 43             ICD10           ICD10 code              NaN            F32.8
# 35           ICD10CM  5-char billing code              NaN           F32.89
# 52           ICD10CM  4-char nonbill code              NaN            F32.8
# 69           ICD10CN           ICD10 code              NaN            F32.9
# 68           ICD10CN           ICD10 code              NaN          F32.802
# 67           ICD10CN           ICD10 code              NaN          F32.801
# 50           ICD10CN           ICD10 code              NaN          F32.902
# 49           ICD10CN           ICD10 code              NaN          F32.800
# 48           ICD10CN           ICD10 code              NaN            F32.8
# 2            ICD10CN           ICD10 code              NaN          F32.901
# 1            ICD10CN           ICD10 code              NaN          F32.900
# 30           ICD10CN      ICD10 Hierarchy              NaN              F32
# 71           ICD10GM      ICD10 Hierarchy              NaN              F32
# 34           ICD10GM           ICD10 code              NaN            F32.8
# 54           ICD10GM           ICD10 code              NaN            F32.9
# 63            ICD9CM   3-dig billing code              NaN              311
# 41              KCD7            KCD7 code              NaN            F32.8
# 40              KCD7            KCD7 code              NaN              F32
# 61              KCD7            KCD7 code              NaN            F32.9
# 45              MeSH                 Drug              NaN          D003863
# 46              MeSH         Main Heading              NaN          D003866
# 70  Nebraska Lexicon     Clinical Finding              NaN        154963001
# 32  Nebraska Lexicon     Clinical Finding              NaN         35489007
# 31  Nebraska Lexicon     Clinical Finding              NaN        307537002
# 3   Nebraska Lexicon     Clinical Finding              NaN        192078003
# 4   Nebraska Lexicon     Clinical Finding              NaN   21061000119107
# 26             OXMIS                OXMIS              NaN            3004A
# 64              Read                 Read              NaN          Eu32z00
# 92              Read                 Read              NaN          Eu32z12
# 91              Read                 Read              NaN          Eu33z11
# 90              Read                 Read              NaN          Eu32.00
# 93              Read                 Read              NaN          Eu32y00
# 25              Read                 Read              NaN          E11..12
# 24              Read                 Read              NaN          E2B..00
# 23              Read                 Read              NaN          Eu32z11
# 66            SNOMED     Clinical Finding                S         35489007
# 88            SNOMED     Clinical Finding              NaN  432601000000107
# 89            SNOMED     Clinical Finding              NaN  444051000000108
# 87            SNOMED     Clinical Finding              NaN  424961000000107
# 86            SNOMED     Clinical Finding              NaN  402441000000102
# 21            SNOMED     Clinical Finding              NaN        154963001
# 33            SNOMED     Clinical Finding              NaN        307537002
# 22            SNOMED     Clinical Finding              NaN  415051000000101
# 51            SNOMED     Clinical Finding              NaN        192078003
# 42            SNOMED     Clinical Finding              NaN  427781000000106
# 62            SNOMED     Clinical Finding              NaN  471451000000102
# 85            SNOMED     Clinical Finding              NaN   21061000119107
# 0             SNOMED     Clinical Finding              NaN  419311000000100
# 53        UK Biobank                Value              NaN           6-1286
