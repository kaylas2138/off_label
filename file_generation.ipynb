# %%
import pandas as pd
import numpy as np
import vocab_mappings as vocab
import off_label

# %%
diagnoses0,drugs0 = off_label.returning_lists('Gabapentin',0) 
diagnoses1,drugs1 = off_label.returning_lists('Gabapentin',1) 
diagnoses2,drugs2 = off_label.returning_lists('Gabapentin',2) 
diagnoses3,drugs3 = off_label.returning_lists('Gabapentin',3) 
diagnoses4,drugs4 = off_label.returning_lists('Gabapentin',4) 
diagnoses5,drugs5 = off_label.returning_lists('Gabapentin',5) 
diagnoses6,drugs6 = off_label.returning_lists('Gabapentin',6) 
diagnoses7,drugs7 = off_label.returning_lists('Gabapentin',7) 
diagnoses8,drugs8 = off_label.returning_lists('Gabapentin',8) 
diagnoses9,drugs9 = off_label.returning_lists('Gabapentin',9) 
diagnoses10,drugs10 = off_label.returning_lists('Gabapentin',10) 
diagnoses11,drugs11 = off_label.returning_lists('Gabapentin',11) 
diagnoses12,drugs12 = off_label.returning_lists('Gabapentin',12) 
diagnoses13,drugs13 = off_label.returning_lists('Gabapentin',13) 
diagnoses14,drugs14 = off_label.returning_lists('Gabapentin',14) 
diagnoses15,drugs15 = off_label.returning_lists('Gabapentin',15) 
diagnoses16,drugs16 = off_label.returning_lists('Gabapentin',16) 
diagnoses17,drugs17 = off_label.returning_lists('Gabapentin',17) 
diagnoses18,drugs18 = off_label.returning_lists('Gabapentin',18) 
diagnoses19,drugs19 = off_label.returning_lists('Gabapentin',19) 
diagnoses20,drugs20 = off_label.returning_lists('Gabapentin',20) 
diagnoses21,drugs21 = off_label.returning_lists('Gabapentin',21) 
diagnoses22,drugs22 = off_label.returning_lists('Gabapentin',22) 
diagnoses23,drugs23 = off_label.returning_lists('Gabapentin',23) 
diagnoses24,drugs24 = off_label.returning_lists('Gabapentin',24) 
diagnoses25,drugs25 = off_label.returning_lists('Gabapentin',25) 
diagnoses26,drugs26 = off_label.returning_lists('Gabapentin',26) 
diagnoses27,drugs27 = off_label.returning_lists('Gabapentin',27)

# %%
std_diag_dict0 = vocab.diag_ICD_SNOMED(diagnoses0)
std_diag_dict1 = vocab.diag_ICD_SNOMED(diagnoses1)
std_diag_dict2 = vocab.diag_ICD_SNOMED(diagnoses2)
std_diag_dict3 = vocab.diag_ICD_SNOMED(diagnoses3)
std_diag_dict4 = vocab.diag_ICD_SNOMED(diagnoses4)
std_diag_dict5 = vocab.diag_ICD_SNOMED(diagnoses5)
std_diag_dict6 = vocab.diag_ICD_SNOMED(diagnoses6)
std_diag_dict7 = vocab.diag_ICD_SNOMED(diagnoses7)
std_diag_dict8 = vocab.diag_ICD_SNOMED(diagnoses8)
std_diag_dict9 = vocab.diag_ICD_SNOMED(diagnoses9)
std_diag_dict10 = vocab.diag_ICD_SNOMED(diagnoses10)
std_diag_dict11 = vocab.diag_ICD_SNOMED(diagnoses11)
std_diag_dict12 = vocab.diag_ICD_SNOMED(diagnoses12)
std_diag_dict13 = vocab.diag_ICD_SNOMED(diagnoses13)
std_diag_dict14 = vocab.diag_ICD_SNOMED(diagnoses14)
std_diag_dict15 = vocab.diag_ICD_SNOMED(diagnoses15)
std_diag_dict16 = vocab.diag_ICD_SNOMED(diagnoses16)
std_diag_dict17 = vocab.diag_ICD_SNOMED(diagnoses17)
std_diag_dict18 = vocab.diag_ICD_SNOMED(diagnoses18)
std_diag_dict19 = vocab.diag_ICD_SNOMED(diagnoses19)
std_diag_dict20 = vocab.diag_ICD_SNOMED(diagnoses20)
std_diag_dict21 = vocab.diag_ICD_SNOMED(diagnoses21)
std_diag_dict22 = vocab.diag_ICD_SNOMED(diagnoses22)
std_diag_dict23 = vocab.diag_ICD_SNOMED(diagnoses23)
std_diag_dict24 = vocab.diag_ICD_SNOMED(diagnoses24)
std_diag_dict25 = vocab.diag_ICD_SNOMED(diagnoses25)
std_diag_dict26 = vocab.diag_ICD_SNOMED(diagnoses26)
std_diag_dict27 = vocab.diag_ICD_SNOMED(diagnoses27)

# %%
diag_MeSH_dict0 = vocab.diag_ICD_MeSH(std_diag_dict0)
diag_MeSH_dict1 = vocab.diag_ICD_MeSH(std_diag_dict1)
diag_MeSH_dict2 = vocab.diag_ICD_MeSH(std_diag_dict2)
diag_MeSH_dict3 = vocab.diag_ICD_MeSH(std_diag_dict3)
diag_MeSH_dict4 = vocab.diag_ICD_MeSH(std_diag_dict4)
diag_MeSH_dict5 = vocab.diag_ICD_MeSH(std_diag_dict5)
diag_MeSH_dict6 = vocab.diag_ICD_MeSH(std_diag_dict6)
diag_MeSH_dict7 = vocab.diag_ICD_MeSH(std_diag_dict7)
diag_MeSH_dict8 = vocab.diag_ICD_MeSH(std_diag_dict8)
diag_MeSH_dict9 = vocab.diag_ICD_MeSH(std_diag_dict9)
diag_MeSH_dict10 = vocab.diag_ICD_MeSH(std_diag_dict10)
diag_MeSH_dict11 = vocab.diag_ICD_MeSH(std_diag_dict11)
diag_MeSH_dict12 = vocab.diag_ICD_MeSH(std_diag_dict12)
diag_MeSH_dict13 = vocab.diag_ICD_MeSH(std_diag_dict13)
diag_MeSH_dict14 = vocab.diag_ICD_MeSH(std_diag_dict14)
diag_MeSH_dict15 = vocab.diag_ICD_MeSH(std_diag_dict15)
diag_MeSH_dict16 = vocab.diag_ICD_MeSH(std_diag_dict16)
diag_MeSH_dict17 = vocab.diag_ICD_MeSH(std_diag_dict17)
diag_MeSH_dict18 = vocab.diag_ICD_MeSH(std_diag_dict18)
diag_MeSH_dict19 = vocab.diag_ICD_MeSH(std_diag_dict19)
diag_MeSH_dict20 = vocab.diag_ICD_MeSH(std_diag_dict20)
diag_MeSH_dict21 = vocab.diag_ICD_MeSH(std_diag_dict21)
diag_MeSH_dict22 = vocab.diag_ICD_MeSH(std_diag_dict22)
diag_MeSH_dict23 = vocab.diag_ICD_MeSH(std_diag_dict23)
diag_MeSH_dict24 = vocab.diag_ICD_MeSH(std_diag_dict24)
diag_MeSH_dict25 = vocab.diag_ICD_MeSH(std_diag_dict25)
diag_MeSH_dict26 = vocab.diag_ICD_MeSH(std_diag_dict26)
diag_MeSH_dict27 = vocab.diag_ICD_MeSH(std_diag_dict27)

# %%
all_snomed_diag0 = vocab.get_related(std_diag_dict0)
all_snomed_diag1 = vocab.get_related(std_diag_dict1)
all_snomed_diag2 = vocab.get_related(std_diag_dict2)
all_snomed_diag3 = vocab.get_related(std_diag_dict3)
all_snomed_diag4 = vocab.get_related(std_diag_dict4)
all_snomed_diag5 = vocab.get_related(std_diag_dict5)
all_snomed_diag6 = vocab.get_related(std_diag_dict6)
all_snomed_diag7 = vocab.get_related(std_diag_dict7)
all_snomed_diag8 = vocab.get_related(std_diag_dict8)
all_snomed_diag9 = vocab.get_related(std_diag_dict9)
all_snomed_diag10 = vocab.get_related(std_diag_dict10)
all_snomed_diag11 = vocab.get_related(std_diag_dict11)
all_snomed_diag12 = vocab.get_related(std_diag_dict12)
all_snomed_diag13 = vocab.get_related(std_diag_dict13)
all_snomed_diag14 = vocab.get_related(std_diag_dict14)
all_snomed_diag15 = vocab.get_related(std_diag_dict15)
all_snomed_diag16 = vocab.get_related(std_diag_dict16)
all_snomed_diag17 = vocab.get_related(std_diag_dict17)
all_snomed_diag18 = vocab.get_related(std_diag_dict18)
all_snomed_diag19 = vocab.get_related(std_diag_dict19)
all_snomed_diag20 = vocab.get_related(std_diag_dict20)
all_snomed_diag21 = vocab.get_related(std_diag_dict21)
all_snomed_diag22 = vocab.get_related(std_diag_dict22)
all_snomed_diag23 = vocab.get_related(std_diag_dict23)
all_snomed_diag24 = vocab.get_related(std_diag_dict24)
all_snomed_diag25 = vocab.get_related(std_diag_dict25)
all_snomed_diag26 = vocab.get_related(std_diag_dict26)
all_snomed_diag27 = vocab.get_related(std_diag_dict27)

# %%
hierarchy_diag0, snomed_parent_diag0, snomed_child0 = vocab.get_hierarchy(std_diag_dict0)
hierarchy_diag1, snomed_parent_diag1, snomed_child1 = vocab.get_hierarchy(std_diag_dict1)
hierarchy_diag2, snomed_parent_diag2, snomed_child2 = vocab.get_hierarchy(std_diag_dict2)
hierarchy_diag3, snomed_parent_diag3, snomed_child3 = vocab.get_hierarchy(std_diag_dict3)
hierarchy_diag4, snomed_parent_diag4, snomed_child4 = vocab.get_hierarchy(std_diag_dict4)
hierarchy_diag5, snomed_parent_diag5, snomed_child5 = vocab.get_hierarchy(std_diag_dict5)
hierarchy_diag6, snomed_parent_diag6, snomed_child6 = vocab.get_hierarchy(std_diag_dict6)
hierarchy_diag7, snomed_parent_diag7, snomed_child7 = vocab.get_hierarchy(std_diag_dict7)
hierarchy_diag8, snomed_parent_diag8, snomed_child8 = vocab.get_hierarchy(std_diag_dict8)
hierarchy_diag9, snomed_parent_diag9, snomed_child9 = vocab.get_hierarchy(std_diag_dict9)
hierarchy_diag10, snomed_parent_diag10, snomed_child10 = vocab.get_hierarchy(std_diag_dict10)
hierarchy_diag11, snomed_parent_diag11, snomed_child11 = vocab.get_hierarchy(std_diag_dict11)
hierarchy_diag12, snomed_parent_diag12, snomed_child12 = vocab.get_hierarchy(std_diag_dict12)
hierarchy_diag13, snomed_parent_diag13, snomed_child13 = vocab.get_hierarchy(std_diag_dict13)
hierarchy_diag14, snomed_parent_diag14, snomed_child14 = vocab.get_hierarchy(std_diag_dict14)
hierarchy_diag15, snomed_parent_diag15, snomed_child15 = vocab.get_hierarchy(std_diag_dict15)
hierarchy_diag16, snomed_parent_diag16, snomed_child16 = vocab.get_hierarchy(std_diag_dict16)
hierarchy_diag17, snomed_parent_diag17, snomed_child17 = vocab.get_hierarchy(std_diag_dict17)
hierarchy_diag18, snomed_parent_diag18, snomed_child18 = vocab.get_hierarchy(std_diag_dict18)
hierarchy_diag19, snomed_parent_diag19, snomed_child19 = vocab.get_hierarchy(std_diag_dict19)
hierarchy_diag20, snomed_parent_diag20, snomed_child20 = vocab.get_hierarchy(std_diag_dict20)
hierarchy_diag21, snomed_parent_diag21, snomed_child21 = vocab.get_hierarchy(std_diag_dict21)
hierarchy_diag22, snomed_parent_diag22, snomed_child22 = vocab.get_hierarchy(std_diag_dict22)
hierarchy_diag23, snomed_parent_diag23, snomed_child23 = vocab.get_hierarchy(std_diag_dict23)
hierarchy_diag24, snomed_parent_diag24, snomed_child24 = vocab.get_hierarchy(std_diag_dict24)
hierarchy_diag25, snomed_parent_diag25, snomed_child25 = vocab.get_hierarchy(std_diag_dict25)
hierarchy_diag26, snomed_parent_diag26, snomed_child26 = vocab.get_hierarchy(std_diag_dict26)
hierarchy_diag27, snomed_parent_diag27, snomed_child27 = vocab.get_hierarchy(std_diag_dict27)

# %%
diagnoses0.to_csv('diagnoses0.csv')
diagnoses1.to_csv('diagnoses1.csv')
diagnoses2.to_csv('diagnoses2.csv')
diagnoses3.to_csv('diagnoses3.csv')
diagnoses4.to_csv('diagnoses4.csv')
diagnoses5.to_csv('diagnoses5.csv')
diagnoses6.to_csv('diagnoses6.csv')
diagnoses7.to_csv('diagnoses7.csv')
diagnoses8.to_csv('diagnoses8.csv')
diagnoses9.to_csv('diagnoses9.csv')
diagnoses10.to_csv('diagnoses10.csv')
diagnoses11.to_csv('diagnoses11.csv')
diagnoses12.to_csv('diagnoses12.csv')
diagnoses13.to_csv('diagnoses13.csv')
diagnoses14.to_csv('diagnoses14.csv')
diagnoses15.to_csv('diagnoses15.csv')
diagnoses16.to_csv('diagnoses16.csv')
diagnoses17.to_csv('diagnoses17.csv')
diagnoses18.to_csv('diagnoses18.csv')
diagnoses19.to_csv('diagnoses19.csv')
diagnoses20.to_csv('diagnoses20.csv')
diagnoses21.to_csv('diagnoses21.csv')
diagnoses22.to_csv('diagnoses22.csv')
diagnoses23.to_csv('diagnoses23.csv')
diagnoses24.to_csv('diagnoses24.csv')
diagnoses25.to_csv('diagnoses25.csv')
diagnoses26.to_csv('diagnoses26.csv')
diagnoses27.to_csv('diagnoses27.csv')

# %%
drugs0.to_csv('drugs0.csv')
drugs1.to_csv('drugs1.csv')
drugs2.to_csv('drugs2.csv')
drugs3.to_csv('drugs3.csv')
drugs4.to_csv('drugs4.csv')
drugs5.to_csv('drugs5.csv')
drugs6.to_csv('drugs6.csv')
drugs7.to_csv('drugs7.csv')
drugs8.to_csv('drugs8.csv')
drugs9.to_csv('drugs9.csv')
drugs10.to_csv('drugs10.csv')
drugs11.to_csv('drugs11.csv')
drugs12.to_csv('drugs12.csv')
drugs13.to_csv('drugs13.csv')
drugs14.to_csv('drugs14.csv')
drugs15.to_csv('drugs15.csv')
drugs16.to_csv('drugs16.csv')
drugs17.to_csv('drugs17.csv')
drugs18.to_csv('drugs18.csv')
drugs19.to_csv('drugs19.csv')
drugs20.to_csv('drugs20.csv')
drugs21.to_csv('drugs21.csv')
drugs22.to_csv('drugs22.csv')
drugs23.to_csv('drugs23.csv')
drugs24.to_csv('drugs24.csv')
drugs25.to_csv('drugs25.csv')
drugs26.to_csv('drugs26.csv')
drugs27.to_csv('drugs27.csv')

# %%
import json

# %%
with open('std_diag_dict0.json', 'w') as fp: json.dump(std_diag_dict0, fp)
with open('std_diag_dict1.json', 'w') as fp: json.dump(std_diag_dict1, fp)
with open('std_diag_dict2.json', 'w') as fp: json.dump(std_diag_dict2, fp)
with open('std_diag_dict3.json', 'w') as fp: json.dump(std_diag_dict3, fp)
with open('std_diag_dict4.json', 'w') as fp: json.dump(std_diag_dict4, fp)
with open('std_diag_dict5.json', 'w') as fp: json.dump(std_diag_dict5, fp)
with open('std_diag_dict6.json', 'w') as fp: json.dump(std_diag_dict6, fp)
with open('std_diag_dict7.json', 'w') as fp: json.dump(std_diag_dict7, fp)
with open('std_diag_dict8.json', 'w') as fp: json.dump(std_diag_dict8, fp)
with open('std_diag_dict9.json', 'w') as fp: json.dump(std_diag_dict9, fp)
with open('std_diag_dict10.json', 'w') as fp: json.dump(std_diag_dict10, fp)
with open('std_diag_dict11.json', 'w') as fp: json.dump(std_diag_dict11, fp)
with open('std_diag_dict12.json', 'w') as fp: json.dump(std_diag_dict12, fp)
with open('std_diag_dict13.json', 'w') as fp: json.dump(std_diag_dict13, fp)
with open('std_diag_dict14.json', 'w') as fp: json.dump(std_diag_dict14, fp)
with open('std_diag_dict15.json', 'w') as fp: json.dump(std_diag_dict15, fp)
with open('std_diag_dict16.json', 'w') as fp: json.dump(std_diag_dict16, fp)
with open('std_diag_dict17.json', 'w') as fp: json.dump(std_diag_dict17, fp)
with open('std_diag_dict18.json', 'w') as fp: json.dump(std_diag_dict18, fp)
with open('std_diag_dict19.json', 'w') as fp: json.dump(std_diag_dict19, fp)
with open('std_diag_dict20.json', 'w') as fp: json.dump(std_diag_dict20, fp)
with open('std_diag_dict21.json', 'w') as fp: json.dump(std_diag_dict21, fp)
with open('std_diag_dict22.json', 'w') as fp: json.dump(std_diag_dict22, fp)
with open('std_diag_dict23.json', 'w') as fp: json.dump(std_diag_dict23, fp)
with open('std_diag_dict24.json', 'w') as fp: json.dump(std_diag_dict24, fp)
with open('std_diag_dict25.json', 'w') as fp: json.dump(std_diag_dict25, fp)
with open('std_diag_dict26.json', 'w') as fp: json.dump(std_diag_dict26, fp)
with open('std_diag_dict27.json', 'w') as fp: json.dump(std_diag_dict27, fp)
    
with open('diag_MeSH_dict0.json', 'w') as fp: json.dump(diag_MeSH_dict0, fp)
with open('diag_MeSH_dict1.json', 'w') as fp: json.dump(diag_MeSH_dict1, fp)
with open('diag_MeSH_dict2.json', 'w') as fp: json.dump(diag_MeSH_dict2, fp)
with open('diag_MeSH_dict3.json', 'w') as fp: json.dump(diag_MeSH_dict3, fp)
with open('diag_MeSH_dict4.json', 'w') as fp: json.dump(diag_MeSH_dict4, fp)
with open('diag_MeSH_dict5.json', 'w') as fp: json.dump(diag_MeSH_dict5, fp)
with open('diag_MeSH_dict6.json', 'w') as fp: json.dump(diag_MeSH_dict6, fp)
with open('diag_MeSH_dict7.json', 'w') as fp: json.dump(diag_MeSH_dict7, fp)
with open('diag_MeSH_dict8.json', 'w') as fp: json.dump(diag_MeSH_dict8, fp)
with open('diag_MeSH_dict9.json', 'w') as fp: json.dump(diag_MeSH_dict9, fp)
with open('diag_MeSH_dict10.json', 'w') as fp: json.dump(diag_MeSH_dict10, fp)
with open('diag_MeSH_dict11.json', 'w') as fp: json.dump(diag_MeSH_dict11, fp)
with open('diag_MeSH_dict12.json', 'w') as fp: json.dump(diag_MeSH_dict12, fp)
with open('diag_MeSH_dict13.json', 'w') as fp: json.dump(diag_MeSH_dict13, fp)
with open('diag_MeSH_dict14.json', 'w') as fp: json.dump(diag_MeSH_dict14, fp)
with open('diag_MeSH_dict15.json', 'w') as fp: json.dump(diag_MeSH_dict15, fp)
with open('diag_MeSH_dict16.json', 'w') as fp: json.dump(diag_MeSH_dict16, fp)
with open('diag_MeSH_dict17.json', 'w') as fp: json.dump(diag_MeSH_dict17, fp)
with open('diag_MeSH_dict18.json', 'w') as fp: json.dump(diag_MeSH_dict18, fp)
with open('diag_MeSH_dict19.json', 'w') as fp: json.dump(diag_MeSH_dict19, fp)
with open('diag_MeSH_dict20.json', 'w') as fp: json.dump(diag_MeSH_dict20, fp)
with open('diag_MeSH_dict21.json', 'w') as fp: json.dump(diag_MeSH_dict21, fp)
with open('diag_MeSH_dict22.json', 'w') as fp: json.dump(diag_MeSH_dict22, fp)
with open('diag_MeSH_dict23.json', 'w') as fp: json.dump(diag_MeSH_dict23, fp)
with open('diag_MeSH_dict24.json', 'w') as fp: json.dump(diag_MeSH_dict24, fp)
with open('diag_MeSH_dict25.json', 'w') as fp: json.dump(diag_MeSH_dict25, fp)
with open('diag_MeSH_dict26.json', 'w') as fp: json.dump(diag_MeSH_dict26, fp)
with open('diag_MeSH_dict27.json', 'w') as fp: json.dump(diag_MeSH_dict27, fp)

# %%
with open('all_snomed_diag0.json', 'w') as fp: json.dump(all_snomed_diag0, fp)
with open('all_snomed_diag1.json', 'w') as fp: json.dump(all_snomed_diag1, fp)
with open('all_snomed_diag2.json', 'w') as fp: json.dump(all_snomed_diag2, fp)
with open('all_snomed_diag3.json', 'w') as fp: json.dump(all_snomed_diag3, fp)
with open('all_snomed_diag4.json', 'w') as fp: json.dump(all_snomed_diag4, fp)
with open('all_snomed_diag5.json', 'w') as fp: json.dump(all_snomed_diag5, fp)
with open('all_snomed_diag6.json', 'w') as fp: json.dump(all_snomed_diag6, fp)
with open('all_snomed_diag7.json', 'w') as fp: json.dump(all_snomed_diag7, fp)
with open('all_snomed_diag8.json', 'w') as fp: json.dump(all_snomed_diag8, fp)
with open('all_snomed_diag9.json', 'w') as fp: json.dump(all_snomed_diag9, fp)
with open('all_snomed_diag10.json', 'w') as fp: json.dump(all_snomed_diag10, fp)
with open('all_snomed_diag11.json', 'w') as fp: json.dump(all_snomed_diag11, fp)
with open('all_snomed_diag12.json', 'w') as fp: json.dump(all_snomed_diag12, fp)
with open('all_snomed_diag13.json', 'w') as fp: json.dump(all_snomed_diag13, fp)
with open('all_snomed_diag14.json', 'w') as fp: json.dump(all_snomed_diag14, fp)
with open('all_snomed_diag15.json', 'w') as fp: json.dump(all_snomed_diag15, fp)
with open('all_snomed_diag16.json', 'w') as fp: json.dump(all_snomed_diag16, fp)
with open('all_snomed_diag17.json', 'w') as fp: json.dump(all_snomed_diag17, fp)
with open('all_snomed_diag18.json', 'w') as fp: json.dump(all_snomed_diag18, fp)
with open('all_snomed_diag19.json', 'w') as fp: json.dump(all_snomed_diag19, fp)
with open('all_snomed_diag20.json', 'w') as fp: json.dump(all_snomed_diag20, fp)
with open('all_snomed_diag21.json', 'w') as fp: json.dump(all_snomed_diag21, fp)
with open('all_snomed_diag22.json', 'w') as fp: json.dump(all_snomed_diag22, fp)
with open('all_snomed_diag23.json', 'w') as fp: json.dump(all_snomed_diag23, fp)
with open('all_snomed_diag24.json', 'w') as fp: json.dump(all_snomed_diag24, fp)
with open('all_snomed_diag25.json', 'w') as fp: json.dump(all_snomed_diag25, fp)
with open('all_snomed_diag26.json', 'w') as fp: json.dump(all_snomed_diag26, fp)
with open('all_snomed_diag27.json', 'w') as fp: json.dump(all_snomed_diag27, fp)

# %%
with open('hierarchy_diag0.json', 'w') as fp: json.dump(hierarchy_diag0, fp)
with open('hierarchy_diag1.json', 'w') as fp: json.dump(hierarchy_diag1, fp)
with open('hierarchy_diag2.json', 'w') as fp: json.dump(hierarchy_diag2, fp)
with open('hierarchy_diag3.json', 'w') as fp: json.dump(hierarchy_diag3, fp)
with open('hierarchy_diag4.json', 'w') as fp: json.dump(hierarchy_diag4, fp)
with open('hierarchy_diag5.json', 'w') as fp: json.dump(hierarchy_diag5, fp)
with open('hierarchy_diag6.json', 'w') as fp: json.dump(hierarchy_diag6, fp)
with open('hierarchy_diag7.json', 'w') as fp: json.dump(hierarchy_diag7, fp)
with open('hierarchy_diag8.json', 'w') as fp: json.dump(hierarchy_diag8, fp)
with open('hierarchy_diag9.json', 'w') as fp: json.dump(hierarchy_diag9, fp)
with open('hierarchy_diag10.json', 'w') as fp: json.dump(hierarchy_diag10, fp)
with open('hierarchy_diag11.json', 'w') as fp: json.dump(hierarchy_diag11, fp)
with open('hierarchy_diag12.json', 'w') as fp: json.dump(hierarchy_diag12, fp)
with open('hierarchy_diag13.json', 'w') as fp: json.dump(hierarchy_diag13, fp)
with open('hierarchy_diag14.json', 'w') as fp: json.dump(hierarchy_diag14, fp)
with open('hierarchy_diag15.json', 'w') as fp: json.dump(hierarchy_diag15, fp)
with open('hierarchy_diag16.json', 'w') as fp: json.dump(hierarchy_diag16, fp)
with open('hierarchy_diag17.json', 'w') as fp: json.dump(hierarchy_diag17, fp)
with open('hierarchy_diag18.json', 'w') as fp: json.dump(hierarchy_diag18, fp)
with open('hierarchy_diag19.json', 'w') as fp: json.dump(hierarchy_diag19, fp)
with open('hierarchy_diag20.json', 'w') as fp: json.dump(hierarchy_diag20, fp)
with open('hierarchy_diag21.json', 'w') as fp: json.dump(hierarchy_diag21, fp)
with open('hierarchy_diag22.json', 'w') as fp: json.dump(hierarchy_diag22, fp)
with open('hierarchy_diag23.json', 'w') as fp: json.dump(hierarchy_diag23, fp)
with open('hierarchy_diag24.json', 'w') as fp: json.dump(hierarchy_diag24, fp)
with open('hierarchy_diag25.json', 'w') as fp: json.dump(hierarchy_diag25, fp)
with open('hierarchy_diag26.json', 'w') as fp: json.dump(hierarchy_diag26, fp)
with open('hierarchy_diag27.json', 'w') as fp: json.dump(hierarchy_diag27, fp)

with open('snomed_parent_diag0.json', 'w') as fp: json.dump(snomed_parent_diag0, fp)
with open('snomed_parent_diag1.json', 'w') as fp: json.dump(snomed_parent_diag1, fp)
with open('snomed_parent_diag2.json', 'w') as fp: json.dump(snomed_parent_diag2, fp)
with open('snomed_parent_diag3.json', 'w') as fp: json.dump(snomed_parent_diag3, fp)
with open('snomed_parent_diag4.json', 'w') as fp: json.dump(snomed_parent_diag4, fp)
with open('snomed_parent_diag5.json', 'w') as fp: json.dump(snomed_parent_diag5, fp)
with open('snomed_parent_diag6.json', 'w') as fp: json.dump(snomed_parent_diag6, fp)
with open('snomed_parent_diag7.json', 'w') as fp: json.dump(snomed_parent_diag7, fp)
with open('snomed_parent_diag8.json', 'w') as fp: json.dump(snomed_parent_diag8, fp)
with open('snomed_parent_diag9.json', 'w') as fp: json.dump(snomed_parent_diag9, fp)
with open('snomed_parent_diag10.json', 'w') as fp: json.dump(snomed_parent_diag10, fp)
with open('snomed_parent_diag11.json', 'w') as fp: json.dump(snomed_parent_diag11, fp)
with open('snomed_parent_diag12.json', 'w') as fp: json.dump(snomed_parent_diag12, fp)
with open('snomed_parent_diag13.json', 'w') as fp: json.dump(snomed_parent_diag13, fp)
with open('snomed_parent_diag14.json', 'w') as fp: json.dump(snomed_parent_diag14, fp)
with open('snomed_parent_diag15.json', 'w') as fp: json.dump(snomed_parent_diag15, fp)
with open('snomed_parent_diag16.json', 'w') as fp: json.dump(snomed_parent_diag16, fp)
with open('snomed_parent_diag17.json', 'w') as fp: json.dump(snomed_parent_diag17, fp)
with open('snomed_parent_diag18.json', 'w') as fp: json.dump(snomed_parent_diag18, fp)
with open('snomed_parent_diag19.json', 'w') as fp: json.dump(snomed_parent_diag19, fp)
with open('snomed_parent_diag20.json', 'w') as fp: json.dump(snomed_parent_diag20, fp)
with open('snomed_parent_diag21.json', 'w') as fp: json.dump(snomed_parent_diag21, fp)
with open('snomed_parent_diag22.json', 'w') as fp: json.dump(snomed_parent_diag22, fp)
with open('snomed_parent_diag23.json', 'w') as fp: json.dump(snomed_parent_diag23, fp)
with open('snomed_parent_diag24.json', 'w') as fp: json.dump(snomed_parent_diag24, fp)
with open('snomed_parent_diag25.json', 'w') as fp: json.dump(snomed_parent_diag25, fp)
with open('snomed_parent_diag26.json', 'w') as fp: json.dump(snomed_parent_diag26, fp)
with open('snomed_parent_diag27.json', 'w') as fp: json.dump(snomed_parent_diag27, fp)

    
with open('snomed_child0.json', 'w') as fp: json.dump(snomed_child0, fp)
with open('snomed_child1.json', 'w') as fp: json.dump(snomed_child1, fp)
with open('snomed_child2.json', 'w') as fp: json.dump(snomed_child2, fp)
with open('snomed_child3.json', 'w') as fp: json.dump(snomed_child3, fp)
with open('snomed_child4.json', 'w') as fp: json.dump(snomed_child4, fp)
with open('snomed_child5.json', 'w') as fp: json.dump(snomed_child5, fp)
with open('snomed_child6.json', 'w') as fp: json.dump(snomed_child6, fp)
with open('snomed_child7.json', 'w') as fp: json.dump(snomed_child7, fp)
with open('snomed_child8.json', 'w') as fp: json.dump(snomed_child8, fp)
with open('snomed_child9.json', 'w') as fp: json.dump(snomed_child9, fp)
with open('snomed_child10.json', 'w') as fp: json.dump(snomed_child10, fp)
with open('snomed_child11.json', 'w') as fp: json.dump(snomed_child11, fp)
with open('snomed_child12.json', 'w') as fp: json.dump(snomed_child12, fp)
with open('snomed_child13.json', 'w') as fp: json.dump(snomed_child13, fp)
with open('snomed_child14.json', 'w') as fp: json.dump(snomed_child14, fp)
with open('snomed_child15.json', 'w') as fp: json.dump(snomed_child15, fp)
with open('snomed_child16.json', 'w') as fp: json.dump(snomed_child16, fp)
with open('snomed_child17.json', 'w') as fp: json.dump(snomed_child17, fp)
with open('snomed_child18.json', 'w') as fp: json.dump(snomed_child18, fp)
with open('snomed_child19.json', 'w') as fp: json.dump(snomed_child19, fp)
with open('snomed_child20.json', 'w') as fp: json.dump(snomed_child20, fp)
with open('snomed_child21.json', 'w') as fp: json.dump(snomed_child21, fp)
with open('snomed_child22.json', 'w') as fp: json.dump(snomed_child22, fp)
with open('snomed_child23.json', 'w') as fp: json.dump(snomed_child23, fp)
with open('snomed_child24.json', 'w') as fp: json.dump(snomed_child24, fp)
with open('snomed_child25.json', 'w') as fp: json.dump(snomed_child25, fp)
with open('snomed_child26.json', 'w') as fp: json.dump(snomed_child26, fp)
with open('snomed_child27.json', 'w') as fp: json.dump(snomed_child27, fp)

# %%
rxnorm0 = vocab.NDC_RxNorm(drugs0)
rxnorm1 = vocab.NDC_RxNorm(drugs1)
rxnorm2 = vocab.NDC_RxNorm(drugs2)
rxnorm3 = vocab.NDC_RxNorm(drugs3)
rxnorm4 = vocab.NDC_RxNorm(drugs4)
rxnorm5 = vocab.NDC_RxNorm(drugs5)
rxnorm6 = vocab.NDC_RxNorm(drugs6)
rxnorm7 = vocab.NDC_RxNorm(drugs7)
rxnorm8 = vocab.NDC_RxNorm(drugs8)
rxnorm9 = vocab.NDC_RxNorm(drugs9)
rxnorm10 = vocab.NDC_RxNorm(drugs10)
rxnorm11 = vocab.NDC_RxNorm(drugs11)
rxnorm12 = vocab.NDC_RxNorm(drugs12)
rxnorm13 = vocab.NDC_RxNorm(drugs13)
rxnorm14 = vocab.NDC_RxNorm(drugs14)
rxnorm15 = vocab.NDC_RxNorm(drugs15)
rxnorm16 = vocab.NDC_RxNorm(drugs16)
rxnorm17 = vocab.NDC_RxNorm(drugs17)
rxnorm18 = vocab.NDC_RxNorm(drugs18)
rxnorm19 = vocab.NDC_RxNorm(drugs19)
rxnorm20 = vocab.NDC_RxNorm(drugs20)
rxnorm21 = vocab.NDC_RxNorm(drugs21)
rxnorm22 = vocab.NDC_RxNorm(drugs22)
rxnorm23 = vocab.NDC_RxNorm(drugs23)
rxnorm24 = vocab.NDC_RxNorm(drugs24)
rxnorm25 = vocab.NDC_RxNorm(drugs25)
rxnorm26 = vocab.NDC_RxNorm(drugs26)
rxnorm27 = vocab.NDC_RxNorm(drugs27)

# %%
ndfrt0 = vocab.all_ndfrt(rxnorm0)
ndfrt1 = vocab.all_ndfrt(rxnorm1)
ndfrt2 = vocab.all_ndfrt(rxnorm2)
ndfrt3 = vocab.all_ndfrt(rxnorm3)
ndfrt4 = vocab.all_ndfrt(rxnorm4)
ndfrt5 = vocab.all_ndfrt(rxnorm5)
ndfrt6 = vocab.all_ndfrt(rxnorm6)
ndfrt7 = vocab.all_ndfrt(rxnorm7)
ndfrt8 = vocab.all_ndfrt(rxnorm8)
ndfrt9 = vocab.all_ndfrt(rxnorm9)
ndfrt10 = vocab.all_ndfrt(rxnorm10)
ndfrt11 = vocab.all_ndfrt(rxnorm11)
ndfrt12 = vocab.all_ndfrt(rxnorm12)
ndfrt13 = vocab.all_ndfrt(rxnorm13)
ndfrt14 = vocab.all_ndfrt(rxnorm14)
ndfrt15 = vocab.all_ndfrt(rxnorm15)
ndfrt16 = vocab.all_ndfrt(rxnorm16)
ndfrt17 = vocab.all_ndfrt(rxnorm17)
ndfrt18 = vocab.all_ndfrt(rxnorm18)
ndfrt19 = vocab.all_ndfrt(rxnorm19)
ndfrt20 = vocab.all_ndfrt(rxnorm20)
ndfrt21 = vocab.all_ndfrt(rxnorm21)
ndfrt22 = vocab.all_ndfrt(rxnorm22)
ndfrt23 = vocab.all_ndfrt(rxnorm23)
ndfrt24 = vocab.all_ndfrt(rxnorm24)
ndfrt25 = vocab.all_ndfrt(rxnorm25)
ndfrt26 = vocab.all_ndfrt(rxnorm26)
ndfrt27 = vocab.all_ndfrt(rxnorm27)

# %%
list0 = flattened_ndfrt(ndfrt0)
list1 = flattened_ndfrt(ndfrt1)
list2 = flattened_ndfrt(ndfrt2)
list3 = flattened_ndfrt(ndfrt3)
list4 = flattened_ndfrt(ndfrt4)
list5 = flattened_ndfrt(ndfrt5)
list6 = flattened_ndfrt(ndfrt6)
list7 = flattened_ndfrt(ndfrt7)
list8 = flattened_ndfrt(ndfrt8)
list9 = flattened_ndfrt(ndfrt9)
list10 = flattened_ndfrt(ndfrt10)
list11 = flattened_ndfrt(ndfrt11)
list12 = flattened_ndfrt(ndfrt12)
list13 = flattened_ndfrt(ndfrt13)
list14 = flattened_ndfrt(ndfrt14)
list15 = flattened_ndfrt(ndfrt15)
list16 = flattened_ndfrt(ndfrt16)
list17 = flattened_ndfrt(ndfrt17)
list18 = flattened_ndfrt(ndfrt18)
list19 = flattened_ndfrt(ndfrt19)
list20 = flattened_ndfrt(ndfrt20)
list21 = flattened_ndfrt(ndfrt21)
list22 = flattened_ndfrt(ndfrt22)
list23 = flattened_ndfrt(ndfrt23)
list24 = flattened_ndfrt(ndfrt24)
list25 = flattened_ndfrt(ndfrt25)
list26 = flattened_ndfrt(ndfrt26)
list27 = flattened_ndfrt(ndfrt27)

# %%
all_ndfrt_0 = vocab.all_related_NDFRT(std_diag_dict0)
all_ndfrt_1 = vocab.all_related_NDFRT(std_diag_dict1)
all_ndfrt_2 = vocab.all_related_NDFRT(std_diag_dict2)
all_ndfrt_3 = vocab.all_related_NDFRT(std_diag_dict3)
all_ndfrt_4 = vocab.all_related_NDFRT(std_diag_dict4)
all_ndfrt_5 = vocab.all_related_NDFRT(std_diag_dict5)
all_ndfrt_6 = vocab.all_related_NDFRT(std_diag_dict6)
all_ndfrt_7 = vocab.all_related_NDFRT(std_diag_dict7)
all_ndfrt_8 = vocab.all_related_NDFRT(std_diag_dict8)
all_ndfrt_9 = vocab.all_related_NDFRT(std_diag_dict9)
all_ndfrt_10 = vocab.all_related_NDFRT(std_diag_dict10)
all_ndfrt_11 = vocab.all_related_NDFRT(std_diag_dict11)
all_ndfrt_12 = vocab.all_related_NDFRT(std_diag_dict12)
all_ndfrt_13 = vocab.all_related_NDFRT(std_diag_dict13)
all_ndfrt_14 = vocab.all_related_NDFRT(std_diag_dict14)
all_ndfrt_15 = vocab.all_related_NDFRT(std_diag_dict15)
all_ndfrt_16 = vocab.all_related_NDFRT(std_diag_dict16)
all_ndfrt_17 = vocab.all_related_NDFRT(std_diag_dict17)
all_ndfrt_18 = vocab.all_related_NDFRT(std_diag_dict18)
all_ndfrt_19 = vocab.all_related_NDFRT(std_diag_dict19)
all_ndfrt_20 = vocab.all_related_NDFRT(std_diag_dict20)
all_ndfrt_21 = vocab.all_related_NDFRT(std_diag_dict21)
all_ndfrt_22 = vocab.all_related_NDFRT(std_diag_dict22)
all_ndfrt_23 = vocab.all_related_NDFRT(std_diag_dict23)
all_ndfrt_24 = vocab.all_related_NDFRT(std_diag_dict24)
all_ndfrt_25 = vocab.all_related_NDFRT(std_diag_dict25)
all_ndfrt_26 = vocab.all_related_NDFRT(std_diag_dict26)
all_ndfrt_27 = vocab.all_related_NDFRT(std_diag_dict27)

# %%
omop_list0 = omop_indications(list0)
omop_list1 = omop_indications(list1)
omop_list2 = omop_indications(list2)
omop_list3 = omop_indications(list3)
omop_list4 = omop_indications(list4)
omop_list5 = omop_indications(list5)
omop_list6 = omop_indications(list6)
omop_list7 = omop_indications(list7)
omop_list8 = omop_indications(list8)
omop_list9 = omop_indications(list9)
omop_list10 = omop_indications(list10)
omop_list11 = omop_indications(list11)
omop_list12 = omop_indications(list12)
omop_list13 = omop_indications(list13)
omop_list14 = omop_indications(list14)
omop_list15 = omop_indications(list15)
omop_list16 = omop_indications(list16)
omop_list17 = omop_indications(list17)
omop_list18 = omop_indications(list18)
omop_list19 = omop_indications(list19)
omop_list20 = omop_indications(list20)
omop_list21 = omop_indications(list21)
omop_list22 = omop_indications(list22)
omop_list23 = omop_indications(list23)
omop_list24 = omop_indications(list24)
omop_list25 = omop_indications(list25)
omop_list26 = omop_indications(list26)
omop_list27 = omop_indications(list27)
